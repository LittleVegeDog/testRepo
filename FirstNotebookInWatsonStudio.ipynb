# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hongzhao Tan**
#
# 100% Human

# %% [markdown]
# *I am interested in data science because I found using data analysis techniques to analyze teams'/players' in-game behaviors and using machine learning technologies to predict teams'/players' in-game behaviors were very cool.*

# %% [markdown]
# ### The following code implements the Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2

gauss(100) == sum(range(101))
# Out:
# True

# %% [markdown]
# Ordered Items:
# 1. Item one
# 2. Item two
# 3. Item three
# 4. Item four
# 5. Item five
#
# Table:
#
# | col0 | col1 | col2 |
# | ----------- | ----------- | ----------- |
# | cell0.0 | cell0.1 | cell0.2 |
# | cell1.0 | cell1.1 | cell1.2 |
# | cell2.0 | cell2.1 | cell2.2 |
#
# Hyperlink:
# [Link To Youtube](https://www.youtube.com)
